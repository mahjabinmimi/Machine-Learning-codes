# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
 
# Load the Fashion MNIST dataset from Keras
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# %%
 
# Normalize pixel values to range [0, 1]
X_train = X_train / 255.0                                       # Scale training images
X_test = X_test / 255.0                                         # Scale test images

# %%
# Build the model
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),             # Flatten 28x28 images to 784
    tf.keras.layers.Dense(128, activation='relu'),             # Hidden layer with 128 ReLU units
    tf.keras.layers.Dense(10, activation='softmax')            # Output layer for 10 classes
])

# %%
# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
model.fit(X_train, y_train, epochs=10, validation_split=0.1, verbose=1)  # Include validation split
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8216 - loss: 0.5053 - val_accuracy: 0.8547 - val_loss: 0.4265
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8634 - loss: 0.3805 - val_accuracy: 0.8628 - val_loss: 0.3854
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8761 - loss: 0.3415 - val_accuracy: 0.8753 - val_loss: 0.3452
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8844 - loss: 0.3168 - val_accuracy: 0.8557 - val_loss: 0.3825
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8897 - loss: 0.3010 - val_accuracy: 0.8832 - val_loss: 0.3263
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8964 - loss: 0.2837 - val_accuracy: 0.8835 - val_loss: 0.3231
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8991 - loss: 0.2710 - val_accuracy: 0.8835 - val_loss: 0.3237
# Epoch 8/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9039 - loss: 0.2588 - val_accuracy: 0.8912 - val_loss: 0.3157
# Epoch 9/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9067 - loss: 0.2487 - val_accuracy: 0.8842 - val_loss: 0.3360
# Epoch 10/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9110 - loss: 0.2405 - val_accuracy: 0.8873 - val_loss: 0.3311

# %%
# Evaluate on test data
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {test_acc:.2f}")
 
# Optional: Display sample predictions
preds = model.predict(X_test[:5])                            # Predict on first 5 test images
for i, pred in enumerate(preds):
    plt.imshow(X_test[i], cmap='gray')
    plt.title(f"Predicted: {pred.argmax()}, True: {y_test[i]}")
    plt.axis('off')
    plt.show()
